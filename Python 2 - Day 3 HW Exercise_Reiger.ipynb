# %% [markdown]
# # OOP - Polymorphism, & Abstraction

# %% [markdown]
# ## Exercise 1:
# Create an abstract class called Vehicle with
# - color, make, and year private attributes
#
# and abstract method called
# - get_info() which returns all information
# - honk() which returns a string of honking sound
#
# Create Car, Boat, and Bicycle class which is a child class of the Vehicle class.  Then, create an instance of each child class and call get_info() method to print out its information in a user friendly format. Add other methods as you like.

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
    
    """@abstractclass"""   
    
    def __init__(self, color, make, year):
        self.__color = color
        self.__make = make
        self.__year = year        
 
    @abstractmethod
    def get_info():
        pass
               
    @abstractmethod
    def honk():
        pass
    
    def get_color(self):
        return (f"{self.__color}")
    
    def get_make(self):
        return (f"{self.__make}")
    
    def get_year(self):
        return (f"{self.__year}")
               
class Car(Vehicle):
    
    category = "Car"
    def __init__(self, color, make, year):
        super().__init__(color, make, year)
        
    def get_info(self):
        return(f"\nColor: {self.get_color()}\tMake: {self.get_make()}\tYear: {self.get_year()}")
    
    def honk(self):
        return ("HONK!!!")
               
class Boat(Vehicle):
    
    category = "Boat"
    def __init__(self, color, make, year):
        super().__init__(color, make, year)
        
    def get_info(self):
        return(f"\nColor: {self.get_color()}\tMake: {self.get_make()}\tYear: {self.get_year()}")
    
    def honk(self):
        return ("AAA-OOO-GAH!!!")
    
class Bicycle(Vehicle):
    
    category = "Bicycle"
    def __init__(self, color, make, year):
        super().__init__(color, make, year)
        
    def get_info(self):
        return(f"\nColor: {self.get_color()}\tMake: {self.get_make()}\tYear: {self.get_year()}")
    
    def honk(self):
        return ("Ding! Ding! Ding!")
              
c1 = Car("red","Jaguar","2020")
print (c1.get_info())
print (c1.honk())

b1 = Boat("metallic orange","Chris Craft","2011")
print (b1.get_info())
print (b1.honk())

bi1 = Bicycle("blue","Raleigh","1995")
print (bi1.get_info())
print (bi1.honk())
# Out:
# Color: red	Make: Jaguar	Year: 2020
# HONK!!!
#
# Color: metallic orange	Make: Chris Craft	Year: 2011
# AAA-OOO-GAH!!!
#
# Color: blue	Make: Raleigh	Year: 1995
# Ding! Ding! Ding!

# %% [markdown]
# ## Exercise 2:
# Create an abstract class called Person with name and address attributes, and print_info() abstract method.
# 1. Build an Employee class inherited from Person class that
#     - stores hired date and salary attributes
#     - print_info() method that will be used to print out all information about an employee
#     - a method to calculate employee's monthly pay where federal tax is 15%, MD tax is 4.5%, and a local tax is 3%.
#
# 2. Build a Customer class also inherited from Person class that
#     - stores balance attribute
#     - print_info() method that will be used to print out all information about a customer
#
#
# Build any method you need but apply encapsulation at all possible. Then, write a program to show your classes work with multiple employees and customers.
#
# CHALLENGE!!!
# Create an Address class and use it in Person class

# %%
from abc import ABC, abstractmethod

#@abstractclass"""    
class Person(ABC):
    
    """@abstractclass"""   
    
    def __init__(self, name, address):
        
# Exercise statement does not require these attributes to be private

        self.name = name
        self.address = address
  
    @abstractmethod
    def print_info():
        pass
    
class Employee(Person):
    def __init__(self, name, address, date, salary):
        super().__init__(name, address)
        
        self.__date = date
        self.__salary = int(salary)
        
    def print_info(self):
        return (f"\nName: {self.name}\tAddress: {self.address}\tHired Date: {self.__date}\nSalary: ${self.__salary}")
    
    def monthly_pay(self):
        
# federal tax = 15%, MD tax = 4.5%, and a local tax = 3%. Total tax = 22.5%

        return (round(self.__salary/12*.775,2))

class Customer(Person):
    def __init__(self, name, address, balance):
        super().__init__(name, address)
        self.__balance = balance
        
    def print_info(self):
        return (f"\nName: {self.name}\tAddress: {self.address}\nCurrent Balance: ${(self.__balance):,.2f}")
    
   
## -------------------------------------------------------------------------------------------------------------    
 
# Create list of employees and then print information about them

emp_list = []
emp_list.append(Employee("Peter","123 Main Street, Apt 1, Silver Spring, MD 99999", "Today", 60000))
emp_list.append(Employee("James Bond", "The Mews, London, England", "1954", 45000))
emp_list.append(Employee("Bugs Bunny", "Warner Brothers Studios, Culver City, CA","1941", 20000))

i1 = 0
for emp in emp_list:
    print (emp_list[i1].print_info())
    print (f"Monthly pay is: {emp_list[i1].monthly_pay()}")
    i1+=1
 
 
# Create list of customers and then print information about them

cust_list = []
cust_list.append(Customer("Peter","123 Main Street, Apt 1, Silver Spring, MD 99999", 600.375))
cust_list.append(Customer("James Bond", "The Mews, London, England", 450.00))
cust_list.append(Customer("Bugs Bunny", "Warner Brothers Studios, Culver City, CA", 2000.0))

i1 = 0
for cust in cust_list:
    print (cust_list[i1].print_info())
    i1+=1
# Out:
# Name: Peter	Address: 123 Main Street, Apt 1, Silver Spring, MD 99999	Hired Date: Today
# Salary: $60000
# Monthly pay is: 3875.0
#
# Name: James Bond	Address: The Mews, London, England	Hired Date: 1954
# Salary: $45000
# Monthly pay is: 2906.25
#
# Name: Bugs Bunny	Address: Warner Brothers Studios, Culver City, CA	Hired Date: 1941
# Salary: $20000
# Monthly pay is: 1291.67
#
# Name: Peter	Address: 123 Main Street, Apt 1, Silver Spring, MD 99999
# Current Balance: $600.38
#
# Name: James Bond	Address: The Mews, London, England
# Current Balance: $450.00
#
# Name: Bugs Bunny	Address: Warner Brothers Studios, Culver City, CA
# Current Balance: $2,000.00

# %%
### CHALLENGE!!! ###

from abc import ABC, abstractmethod

#@abstractclass"""    
class Person(ABC):
    
    """@abstractclass"""   
    
    def __init__(self, name, address):
        
# In this version I make "name" attribute private       
        self.__name = name
        self.address = Address(address)
  
    @abstractmethod
    def print_info():
        pass
    
    def get_name(self):
        return (f"{self.__name}")

class Employee(Person):
    def __init__(self, name, address, date, salary):
        super().__init__(name, address)

        self.__date = date
        self.__salary = int(salary)
        
    def print_info(self):
        return (f"\nName: {self.get_name()}\tAddress: {self.address.get_address()}\tHired Date: {self.__date}\nSalary: ${self.__salary}")
    
    def monthly_pay(self):
        
# federal tax = 15%, MD tax = 4.5%, and a local tax = 3%. Total tax = 22.5%

        return (round(self.__salary/12*.775,2))

class Customer(Person):
    def __init__(self, name, address, balance):
        super().__init__(name, address)
        self.__balance = balance
        
    def print_info(self):
        return (f"\nName: {self.get_name()}\tAddress: {self.address.get_address()}\nCurrent Balance: ${(self.__balance):,.2f}")

class Address():

    def __init__(self,address):
        self.__address = address
        
    def get_address(self):
        return (f"{self.__address}")
   
## -------------------------------------------------------------------------------------------------------------    
 
# Create list of employees and then print information about them

emp_list = []

emp_list.append(Employee("Peter","123 Main Street, Apt 1, Silver Spring, MD 99999", "Today", 60000))
emp_list.append(Employee("James Bond", "The Mews, London, England", "1954", 45000))
emp_list.append(Employee("Bugs Bunny", "Warner Brothers Studios, Culver City, CA","1941", 20000))

i1 = 0
for emp in emp_list:
    print (emp_list[i1].print_info())
    print (f"Monthly pay is: {emp_list[i1].monthly_pay()}")
    i1+=1
 
 
# Create list of customers and then print information about them

cust_list = []
cust_list.append(Customer("Peter","123 Main Street, Apt 1, Silver Spring, MD 99999", 600.375))
cust_list.append(Customer("James Bond", "The Mews, London, England", 450.00))
cust_list.append(Customer("Bugs Bunny", "Warner Brothers Studios, Culver City, CA", 2000.0))

i1 = 0
for cust in cust_list:
    print (cust_list[i1].print_info())
    i1+=1
# Out:
# Name: Peter	Address: 123 Main Street, Apt 1, Silver Spring, MD 99999	Hired Date: Today
# Salary: $60000
# Monthly pay is: 3875.0
#
# Name: James Bond	Address: The Mews, London, England	Hired Date: 1954
# Salary: $45000
# Monthly pay is: 2906.25
#
# Name: Bugs Bunny	Address: Warner Brothers Studios, Culver City, CA	Hired Date: 1941
# Salary: $20000
# Monthly pay is: 1291.67
#
# Name: Peter	Address: 123 Main Street, Apt 1, Silver Spring, MD 99999
# Current Balance: $600.38
#
# Name: James Bond	Address: The Mews, London, England
# Current Balance: $450.00
#
# Name: Bugs Bunny	Address: Warner Brothers Studios, Culver City, CA
# Current Balance: $2,000.00
